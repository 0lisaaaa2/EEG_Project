# %%
import mne
import numpy as np

# %%
print('Hello World')
# Out:
# Hello World

# %%
from mne_bids import (BIDSPath,read_raw_bids)

bids_root = r"Data\ds005841-main"
subject_id = '001'

bids_path = BIDSPath(subject=subject_id,task="P3",session="P3",
                     datatype='eeg', suffix='eeg',
                     root=bids_root)

raw = read_raw_bids(bids_path)
raw.load_data()

# %%
from mne_bids import BIDSPath, read_raw_bids

bids_root = r"Data\ds005841-main"

subject_id = "001"
task = "regfront"    # lumfront, lumperp, regfront, regperp, signalscreen, signalvr

bids_path = BIDSPath(
    subject=subject_id,
    task=task,
    datatype="eeg",
    suffix="eeg",
    extension=".bdf",
    root=bids_root
)

print(bids_path.fpath)

raw = read_raw_bids(bids_path)
raw.load_data()

# Plot continuous EEG
raw.plot()
# Out:
# Data\ds005841-main\sub-001\eeg\sub-001_task-regfront_eeg.bdf
# Extracting EDF parameters from d:\lisa-\Universität_2\Master\2. Semester\EEG\EEG_Project\Data\ds005841-main\sub-001\eeg\sub-001_task-regfront_eeg.bdf...
# BDF file detected
# C:\Users\lisa-\AppData\Local\Temp\ipykernel_31628\1182474308.py:19: RuntimeWarning: Invalid measurement date encountered in the header.
#   raw = read_raw_bids(bids_path)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 19
#       8 bids_path = BIDSPath(
#       9     subject=subject_id,
#      10     task=task,
#    (...)
#      14     root=bids_root
#      15 )
#      17 print(bids_path.fpath)
# ---> 19 raw = read_raw_bids(bids_path)
#      20 raw.load_data()
#      22 # Plot continuous EEG
#
# File <decorator-gen-395>:12, in read_raw_bids(bids_path, extra_params, return_event_dict, verbose)
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne_bids\read.py:1039, in read_raw_bids(bids_path, extra_params, return_event_dict, verbose)
#    1037 if raw_path.suffix == ".fif" and "allow_maxshield" not in extra_params:
#    1038     extra_params["allow_maxshield"] = True
# -> 1039 raw = _read_raw(
#    1040     raw_path,
#    1041     electrode=None,
#    1042     hsp=None,
#    1043     hpi=None,
#    1044     config_path=config_path,
#    1045     **extra_params,
#    1046 )
#    1048 # Try to find an associated events.tsv to get information about the
#    1049 # events in the recorded data
#    1050 if (
#    1051     bids_path.subject == "emptyroom" and bids_path.task == "noise"
#    1052 ) or bids_path.task.startswith("rest"):
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne_bids\read.py:71, in _read_raw(raw_path, electrode, hsp, hpi, allow_maxshield, config_path, **kwargs)
#      69 elif ext in [".ds", ".vhdr", ".set", ".edf", ".bdf", ".EDF", ".snirf", ".cdt"]:
#      70     raw_path = Path(raw_path)
# ---> 71     raw = reader[ext](raw_path, **kwargs)
#      73 # MEF and NWB are allowed, but not yet implemented
#      74 elif ext in [".mef", ".nwb"]:
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\io\edf\edf.py:1834, in read_raw_bdf(input_fname, eog, misc, stim_channel, exclude, infer_types, include, preload, units, encoding, exclude_after_unique, verbose)
#    1832 if ext != "bdf":
#    1833     raise NotImplementedError(f"Only BDF files are supported, got {ext}.")
# -> 1834 return RawEDF(
#    1835     input_fname=input_fname,
#    1836     eog=eog,
#    1837     misc=misc,
#    1838     stim_channel=stim_channel,
#    1839     exclude=exclude,
#    1840     infer_types=infer_types,
#    1841     preload=preload,
#    1842     include=include,
#    1843     units=units,
#    1844     encoding=encoding,
#    1845     exclude_after_unique=exclude_after_unique,
#    1846     verbose=verbose,
#    1847 )
#
# File <decorator-gen-279>:12, in __init__(self, input_fname, eog, misc, stim_channel, exclude, infer_types, preload, include, units, encoding, exclude_after_unique, verbose)
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\io\edf\edf.py:152, in RawEDF.__init__(self, input_fname, eog, misc, stim_channel, exclude, infer_types, preload, include, units, encoding, exclude_after_unique, verbose)
#     150 logger.info(f"Extracting EDF parameters from {input_fname}...")
#     151 input_fname = os.path.abspath(input_fname)
# --> 152 info, edf_info, orig_units = _get_info(
#     153     input_fname,
#     154     stim_channel,
#     155     eog,
#     156     misc,
#     157     exclude,
#     158     infer_types,
#     159     preload,
#     160     include,
#     161     exclude_after_unique,
#     162 )
#     163 logger.info("Creating raw.info structure...")
#     165 _validate_type(units, (str, None, dict), "units")
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\io\edf\edf.py:541, in _get_info(fname, stim_channel, eog, misc, exclude, infer_types, preload, include, exclude_after_unique)
#     538 eog = eog if eog is not None else []
#     539 misc = misc if misc is not None else []
# --> 541 edf_info, orig_units = _read_header(
#     542     fname, exclude, infer_types, include, exclude_after_unique
#     543 )
#     545 # XXX: `tal_ch_names` to pass to `_check_stim_channel` should be computed
#     546 #      from `edf_info['ch_names']` and `edf_info['tal_idx']` but 'tal_idx'
#     547 #      contains stim channels that are not TAL.
#     548 stim_channel_idxs, _ = _check_stim_channel(stim_channel, edf_info["ch_names"])
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\io\edf\edf.py:515, in _read_header(fname, exclude, infer_types, include, exclude_after_unique)
#     513 logger.info(f"{ext.upper()} file detected")
#     514 if ext in ("bdf", "edf"):
# --> 515     return _read_edf_header(
#     516         fname, exclude, infer_types, include, exclude_after_unique
#     517     )
#     518 elif ext == "gdf":
#     519     return _read_gdf_header(fname, exclude, include), None
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\io\edf\edf.py:880, in _read_edf_header(fname, exclude, infer_types, include, exclude_after_unique)
#     877     fid.read(8)  # skip the file's measurement time
#     878     warn("Invalid measurement date encountered in the header.")
# --> 880 header_nbytes = int(_edf_str(fid.read(8)))
#     881 # The following 44 bytes sometimes identify the file type, but this is
#     882 # not guaranteed. Therefore, we skip this field and use the file
#     883 # extension to determine the subtype (EDF or BDF, which differ in the
#     884 # number of bytes they use for the data records; EDF uses 2 bytes
#     885 # whereas BDF uses 3 bytes).
#     886 fid.read(44)
#
# ValueError: invalid literal for int() with base 10: '6fabfa4c'
