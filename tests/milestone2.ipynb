# %%
import mne
from mne_bids import BIDSPath, read_raw_bids
import numpy as np

# %% [markdown]
# ### Info-Dump
#
#
# - 2 Task: Regularity, Luminance
# - 2 Angle: Frontoparallel, Perspective
#
# - 2 Regularity: Symmetry, Asymmetry -> Discriminate symmetry from asymmetry
# - 2 Luminance: Dark, Light          -> Discriminate dark from light stimuli
#
# Task and Angle were blocked. -> One data file per combination (Lumfron, Lumperp etc.)
#
# - Lumfront
# - LumPerp
# - RegFront
# - RegPerp
#
# Events in each task: "Combination of reflection and color conditions"
# - RAND_DARK
# - RAND_LIGHT
# - REF_DARK
# - REF_LIGHT
#
# Hypothesis of what the event types are (not 100% sure!!)
# | Event label  | Likely meaning                                   | Context                           |
# | ------------ | ------------------------------------------------ | --------------------------------- |
# | `RAND_DARK`  | Asymmetrical (random) pattern, dark luminance    | Regularity task or Luminance task |
# | `RAND_LIGHT` | Asymmetrical (random) pattern, light luminance   | ""                                |
# | `REF_DARK`   | Symmetrical (reflected) pattern, dark luminance  | ""                                |
# | `REF_LIGHT`  | Symmetrical (reflected) pattern, light luminance | ""                                |
#
# In Regularity task blocks:
# - Participants attend to symmetry, ignore luminance (but events still mark both features).
#
# In Luminance task blocks:
# - Participants attend to light/dark, ignore regularity (but events still mark both features).
#
#
# After above tasks, this was done to check EEG data quality in VR compared to monitor (not included in hypothesis testing)
# - Signalscreen  -> Monitor
# - Signalvr      -> With VR headset on

# %% [markdown]
# ### Questions
#
# Are there only 4 events/stimuli per file/task type?? Why is it recorded for a much longer time then?

# %%
# read in data for a specific subject and task
bids_root = "ds005841-download"

subject_id = "001"
task = "regfront"    # lumfront, lumperp, regfront, regperp, signalscreen, signalvr -> Was ist signalscreen, signalvr?

bids_path = BIDSPath(
    subject=subject_id,
    task=task,
    datatype="eeg",
    suffix="eeg",
    extension=".bdf",
    root=bids_root
)

#print(bids_path.fpath)

raw = read_raw_bids(bids_path)
raw.load_data()

raw.filter(0.1,40, fir_design='firwin')
# Out:
# Extracting EDF parameters from d:\lisa-\Universität_2\Master\2. Semester\EEG\EEG_Project\ds005841-download\sub-001\eeg\sub-001_task-regfront_eeg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from ds005841-download\sub-001\eeg\sub-001_task-regfront_events.tsv.
# Reading 0 ... 183807  =      0.000 ...   358.998 secs...
# C:\Users\lisa-\AppData\Local\Temp\ipykernel_31808\2114536555.py:18: RuntimeWarning: Did not find any channels.tsv associated with sub-001_task-regfront.
#
# The search_str was "ds005841-download\sub-001\**\eeg\sub-001*channels.tsv"
#   raw = read_raw_bids(bids_path)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 16897 samples (33.002 s)
# <RawEDF | sub-001_task-regfront_eeg.bdf, 73 x 183808 (359.0 s), ~102.4 MiB, data loaded>

# %%
# get events and event id mapping
events_names, event_id = mne.events_from_annotations(raw) # only contains event-types (keep event_id for mapping of stimuli)
events = mne.find_events(raw, stim_channel="Status", initial_event=True) # actual stimuli from the "Status" channel

print("Moin ", event_id)
print(f"Found {len(events)} events")
print("Unique codes:", np.unique(events[:, 2]))
# Out:
# Used Annotations descriptions: ['RAND_DARK', 'RAND_LIGHT', 'REF_DARK', 'REF_LIGHT']
# Finding events on: Status
# 130 events found on stim channel Status
# Event IDs: [    1     2     3     4    55 65536]
# Moin  {'RAND_DARK': 1, 'RAND_LIGHT': 2, 'REF_DARK': 3, 'REF_LIGHT': 4}
# Found 130 events
# Unique codes: [    1     2     3     4    55 65536]

# %%
# annotations only contain general event types, not the actual stimuli
for ann in raw.annotations: 
    print(f"{ann['description']}: onset={ann['onset']}, duration={ann['duration']}")
# Out:
# RAND_DARK: onset=1.5, duration=0.5
# RAND_LIGHT: onset=2.0, duration=0.5
# REF_DARK: onset=2.5, duration=0.5
# REF_LIGHT: onset=3.0, duration=0.5

# %%
#print(raw.info['ch_names'])

# %%
print(raw.info['projs'])
print(raw.info['chs'][0])  # Info about first channel
# Out:
# []
# {'cal': 1.0, 'logno': 1, 'scanno': 1, 'range': 1.0, 'unit_mul': 0 (FIFF_UNITM_NONE), 'ch_name': 'Fp1', 'unit': 107 (FIFF_UNIT_V), 'coord_frame': 4 (FIFFV_COORD_HEAD), 'coil_type': 1 (FIFFV_COIL_EEG), 'kind': 2 (FIFFV_EEG_CH), 'loc': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])}

# %% [markdown]
# Sim channel = Status -> has 129 events (128 regular event + '55' event once to start off)
#
# 55 is a "junk" trigger
# - This is a typical BioSemi artifact:
# - 55 often appears as a status reset, button press, start packet, or Unity VR sync pulse
# - It should be ignored.
#
# The dataset does not store each trial in the .tsv.
# The .tsv is only a mapping table.

# %%
# remove junk events (code 55)
if task == "regfront":
    valid_codes = [1,2,3,4]
    event_names = {
    1: "RAND_DARK",
    2: "RAND_LIGHT",
    3: "REF_DARK",
    4: "REF_LIGHT"
    }
elif task == "regperp":
    valid_codes = [5,6,7,8]
    event_names = {
    5: "RAND_DARK",
    6: "RAND_LIGHT",
    7: "REF_DARK",
    8: "REF_LIGHT"
    }
elif task == "lumfront":
    valid_codes = [11,12,13,14]
    event_names = {
    11: "RAND_DARK",
    12: "RAND_LIGHT",
    13: "REF_DARK",
    14: "REF_LIGHT"
    }
elif task == "lumperp":
    valid_codes = [15,16,17,18]
    event_names = {
    15: "RAND_DARK",
    16: "RAND_LIGHT",
    17: "REF_DARK",
    18: "REF_LIGHT"
    }
else:
    print("help")

print("Valid codes:", valid_codes)
clean_events = events[np.isin(events[:, 2], valid_codes)]
#event_names = {v: k for k, v in event_id.items()} # idk but needs inverted mapping
#print(event_names)

# correctly annotate: 
annotations = mne.annotations_from_events(
    events=clean_events,
    event_desc=event_names,      
    sfreq=raw.info["sfreq"]
)

raw.set_annotations(annotations)
# Out:
# Valid codes: [1, 2, 3, 4]
# <RawEDF | sub-001_task-regfront_eeg.bdf, 73 x 183808 (359.0 s), ~102.4 MiB, data loaded>

# %%
# %matplotlib qt
print(event_id)
# raw.plot(
#     events=clean_events,
#     #event_id=event_id,
#     #event_color={"RAND_DARK": "blue", "RAND_LIGHT": "orange",
#     #             "REF_DARK": "green", "REF_LIGHT": "purple"},
#     duration=10,
#     scalings="auto",
#     n_channels=32,
#     #block=True
# )

#raw.filter(0.5,50, fir_design='firwin')
raw.plot(block=True, scalings=40e-6, duration=10)
#raw.plot(block=True)
# Out:
# {'RAND_DARK': 1, 'RAND_LIGHT': 2, 'REF_DARK': 3, 'REF_LIGHT': 4}
# Channels marked as bad:
# none
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 15
#       2 print(event_id)
#       3 # raw.plot(
#       4 #     events=clean_events,
#       5 #     #event_id=event_id,
#    (...)
#      13
#      14 #raw.filter(0.5,50, fir_design='firwin')
# ---> 15 raw.plot(block=True, scalings=40e-6, duration=10)
#      16 #raw.plot(block=True)
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\io\base.py:1944, in BaseRaw.plot(self, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id, show_scrollbars, show_scalebars, time_format, precompute, use_opengl, picks, theme, overview_mode, splash, verbose)
#    1903 @copy_function_doc_to_method_doc(plot_raw)
#    1904 def plot(
#    1905     self,
#    (...)
#    1942     verbose=None,
#    1943 ):
# -> 1944     return plot_raw(
#    1945         self,
#    1946         events,
#    1947         duration,
#    1948         start,
#    1949         n_channels,
#    1950         bgcolor,
#    1951         color,
#    1952         bad_color,
#    1953         event_color,
#    1954         scalings,
#    1955         remove_dc,
#    1956         order,
#    1957         show_options,
#    1958         title,
#    1959         show,
#    1960         block,
#    1961         highpass,
#    1962         lowpass,
#    1963         filtorder,
#    1964         clipping,
#    1965         show_first_samp,
#    1966         proj,
#    1967         group_by,
#    1968         butterfly,
#    1969         decim,
#    1970         noise_cov=noise_cov,
#    1971         event_id=event_id,
#    1972         show_scrollbars=show_scrollbars,
#    1973         show_scalebars=show_scalebars,
#    1974         time_format=time_format,
#    1975         precompute=precompute,
#    1976         use_opengl=use_opengl,
#    1977         picks=picks,
#    1978         theme=theme,
#    1979         overview_mode=overview_mode,
#    1980         splash=splash,
#    1981         verbose=verbose,
#    1982     )
#
# File <decorator-gen-207>:12, in plot_raw(raw, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id, show_scrollbars, show_scalebars, time_format, precompute, use_opengl, picks, theme, overview_mode, splash, verbose)
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\viz\raw.py:406, in plot_raw(raw, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id, show_scrollbars, show_scalebars, time_format, precompute, use_opengl, picks, theme, overview_mode, splash, verbose)
#     351 precompute = _handle_precompute(precompute)
#     352 params = dict(
#     353     inst=raw,
#     354     info=info,
#    (...)
#     403     splash=splash,
#     404 )
# --> 406 fig = _get_browser(show=show, block=block, **params)
#     408 return fig
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\viz\_figure.py:743, in _get_browser(show, block, **kwargs)
#     741 # Initialize Browser
#     742 fig = backend._init_browser(**kwargs)
# --> 743 _show_browser(show=show, block=block, fig=fig)
#     745 return fig
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\viz\utils.py:183, in _show_browser(show, block, fig, **kwargs)
#     181     block = False
#     182 if backend == "matplotlib":
# --> 183     plt_show(show, block=block, **kwargs)
#     184 else:
#     185     from qtpy.QtCore import Qt
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\viz\utils.py:158, in plt_show(show, fig, **kwargs)
#     156 if show and backend != "agg":
#     157     logger.debug(f"Showing plot for backend {repr(backend)}")
# --> 158     (fig or plt).show(**kwargs)
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:613, in show(*args, **kwargs)
#     569 """
#     570 Display all open figures.
#     571
#    (...)
#     610 explicitly there.
#     611 """
#     612 _warn_if_gui_out_of_main_thread()
# --> 613 return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backend_bases.py:3550, in _Backend.show(cls, block)
#    3548     block = not ipython_pylab and not is_interactive()
#    3549 if block:
# -> 3550     cls.mainloop()
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backends\backend_qt.py:657, in FigureManagerQT.start_main_loop(cls)
#     655 qapp = QtWidgets.QApplication.instance()
#     656 if qapp:
# --> 657     with _allow_interrupt_qt(qapp):
#     658         qt_compat._exec(qapp)
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backend_bases.py:1660, in _allow_interrupt(prepare_notifier, handle_sigint)
#    1658 signal.signal(signal.SIGINT, old_sigint_handler)
#    1659 if handler_args is not None:
# -> 1660     old_sigint_handler(*handler_args)
#
# KeyboardInterrupt:

# %%
# %matplotlib inline
#fig = mne.viz.plot_events(events, event_id=event_id, sfreq=raw.info["sfreq"], first_samp=raw.first_samp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[134], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 fig = mne.viz.plot_events(events, event_id=event_id, sfreq=raw.info["sfreq"], first_samp=raw.first_samp)
#
# File <decorator-gen-108>:12, in plot_events(events, sfreq, first_samp, color, event_id, axes, equal_spacing, show, on_missing, verbose)
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\viz\misc.py:836, in plot_events(events, sfreq, first_samp, color, event_id, axes, equal_spacing, show, on_missing, verbose)
#     834     if this_event not in unique_events:
#     835         msg = f"{this_event} from event_id is not present in events."
# --> 836         _on_missing(on_missing, msg)
#     837         keep[ii] = False
#     838 conditions = [cond for cond, k in zip(conditions, keep) if k]
#
# File c:\Users\lisa-\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\utils\check.py:1221, in _on_missing(on_missing, msg, name, error_klass)
#    1219 on_missing = "warn" if on_missing == "warning" else on_missing
#    1220 if on_missing == "raise":
# -> 1221     raise error_klass(msg)
#    1222 elif on_missing == "warn":
#    1223     warn(msg)
#
# ValueError: 1 from event_id is not present in events.

# %%
# now: correctly annotated stimuli
for ann in raw.annotations: 
    print(f"{ann['description']}: onset={ann['onset']}, duration={ann['duration']}")
# Out:
# RAND_LIGHT: onset=8.205078, duration=0.0
# REF_LIGHT: onset=10.707031, duration=0.0
# REF_DARK: onset=13.152344, duration=0.0
# RAND_DARK: onset=15.841797, duration=0.0
# RAND_DARK: onset=36.095703, duration=0.0
# RAND_LIGHT: onset=39.210938, duration=0.0
# REF_LIGHT: onset=41.613281, duration=0.0
# REF_DARK: onset=45.5, duration=0.0
# RAND_LIGHT: onset=48.044922, duration=0.0
# REF_DARK: onset=50.369141, duration=0.0
# REF_LIGHT: onset=52.570312, duration=0.0
# REF_DARK: onset=54.916016, duration=0.0
# REF_DARK: onset=57.919922, duration=0.0
# REF_LIGHT: onset=60.064453, duration=0.0
# RAND_DARK: onset=62.466797, duration=0.0
# REF_DARK: onset=64.576172, duration=0.0
# REF_LIGHT: onset=66.876953, duration=0.0
# RAND_DARK: onset=69.111328, duration=0.0
# RAND_LIGHT: onset=71.3125, duration=0.0
# REF_LIGHT: onset=73.511719, duration=0.0
# REF_LIGHT: onset=75.601562, duration=0.0
# RAND_DARK: onset=77.802734, duration=0.0
# RAND_LIGHT: onset=79.869141, duration=0.0
# REF_LIGHT: onset=82.001953, duration=0.0
# RAND_DARK: onset=86.033203, duration=0.0
# REF_DARK: onset=89.517578, duration=0.0
# REF_LIGHT: onset=91.707031, duration=0.0
# REF_LIGHT: onset=93.841797, duration=0.0
# RAND_LIGHT: onset=96.220703, duration=0.0
# REF_DARK: onset=98.398438, duration=0.0
# RAND_DARK: onset=100.464844, duration=0.0
# RAND_DARK: onset=104.955078, duration=0.0
# REF_LIGHT: onset=107.177734, duration=0.0
# REF_DARK: onset=109.277344, duration=0.0
# REF_LIGHT: onset=111.466797, duration=0.0
# RAND_DARK: onset=114.794922, duration=0.0
# RAND_LIGHT: onset=117.0625, duration=0.0
# REF_LIGHT: onset=119.240234, duration=0.0
# RAND_DARK: onset=121.417969, duration=0.0
# RAND_DARK: onset=123.462891, duration=0.0
# REF_DARK: onset=125.863281, duration=0.0
# REF_LIGHT: onset=127.974609, duration=0.0
# REF_DARK: onset=130.064453, duration=0.0
# RAND_LIGHT: onset=133.035156, duration=0.0
# RAND_LIGHT: onset=135.078125, duration=0.0
# RAND_LIGHT: onset=137.167969, duration=0.0
# REF_DARK: onset=139.210938, duration=0.0
# REF_DARK: onset=141.333984, duration=0.0
# RAND_LIGHT: onset=143.478516, duration=0.0
# RAND_LIGHT: onset=147.152344, duration=0.0
# RAND_DARK: onset=149.197266, duration=0.0
# REF_DARK: onset=151.275391, duration=0.0
# RAND_LIGHT: onset=153.396484, duration=0.0
# REF_LIGHT: onset=155.417969, duration=0.0
# REF_LIGHT: onset=157.451172, duration=0.0
# REF_LIGHT: onset=159.796875, duration=0.0
# REF_DARK: onset=161.941406, duration=0.0
# RAND_LIGHT: onset=164.052734, duration=0.0
# REF_LIGHT: onset=167.158203, duration=0.0
# REF_LIGHT: onset=170.027344, duration=0.0
# REF_LIGHT: onset=172.140625, duration=0.0
# REF_DARK: onset=175.667969, duration=0.0
# RAND_LIGHT: onset=177.802734, duration=0.0
# RAND_DARK: onset=179.904297, duration=0.0
# REF_DARK: onset=182.972656, duration=0.0
# RAND_LIGHT: onset=185.050781, duration=0.0
# REF_LIGHT: onset=187.341797, duration=0.0
# RAND_LIGHT: onset=189.564453, duration=0.0
# REF_DARK: onset=191.820312, duration=0.0
# RAND_DARK: onset=193.941406, duration=0.0
# RAND_DARK: onset=196.052734, duration=0.0
# REF_DARK: onset=198.824219, duration=0.0
# RAND_DARK: onset=200.867188, duration=0.0
# RAND_LIGHT: onset=202.933594, duration=0.0
# REF_DARK: onset=205.066406, duration=0.0
# RAND_DARK: onset=207.267578, duration=0.0
# RAND_DARK: onset=209.544922, duration=0.0
# RAND_DARK: onset=211.84375, duration=0.0
# RAND_LIGHT: onset=214.125, duration=0.0
# RAND_DARK: onset=216.236328, duration=0.0
# REF_LIGHT: onset=218.28125, duration=0.0
# RAND_LIGHT: onset=220.425781, duration=0.0
# RAND_DARK: onset=223.642578, duration=0.0
# REF_DARK: onset=225.685547, duration=0.0
# RAND_DARK: onset=227.796875, duration=0.0
# RAND_LIGHT: onset=229.929688, duration=0.0
# REF_DARK: onset=232.230469, duration=0.0
# REF_LIGHT: onset=234.677734, duration=0.0
# REF_DARK: onset=237.123047, duration=0.0
# RAND_LIGHT: onset=239.490234, duration=0.0
# REF_LIGHT: onset=241.658203, duration=0.0
# RAND_LIGHT: onset=243.736328, duration=0.0
# RAND_LIGHT: onset=245.890625, duration=0.0
# RAND_LIGHT: onset=248.037109, duration=0.0
# REF_DARK: onset=250.203125, duration=0.0
# REF_LIGHT: onset=252.28125, duration=0.0
# REF_DARK: onset=254.648438, duration=0.0
# RAND_DARK: onset=256.714844, duration=0.0
# RAND_DARK: onset=258.769531, duration=0.0
# RAND_DARK: onset=260.9375, duration=0.0
# REF_LIGHT: onset=263.082031, duration=0.0
# REF_LIGHT: onset=266.677734, duration=0.0
# REF_LIGHT: onset=268.978516, duration=0.0
# REF_DARK: onset=271.402344, duration=0.0
# RAND_DARK: onset=273.78125, duration=0.0
# RAND_LIGHT: onset=275.916016, duration=0.0
# REF_DARK: onset=278.417969, duration=0.0
# REF_DARK: onset=280.572266, duration=0.0
# RAND_DARK: onset=282.818359, duration=0.0
# RAND_DARK: onset=284.873047, duration=0.0
# REF_DARK: onset=287.251953, duration=0.0
# REF_LIGHT: onset=289.273438, duration=0.0
# REF_LIGHT: onset=291.441406, duration=0.0
# RAND_DARK: onset=293.640625, duration=0.0
# RAND_DARK: onset=295.751953, duration=0.0
# REF_LIGHT: onset=298.208984, duration=0.0
# RAND_DARK: onset=300.376953, duration=0.0
# REF_LIGHT: onset=302.699219, duration=0.0
# REF_DARK: onset=305.011719, duration=0.0
# RAND_LIGHT: onset=307.167969, duration=0.0
# REF_DARK: onset=309.267578, duration=0.0
# RAND_DARK: onset=311.400391, duration=0.0
# REF_DARK: onset=313.486328, duration=0.0
# RAND_LIGHT: onset=315.578125, duration=0.0
# RAND_LIGHT: onset=317.710938, duration=0.0
# RAND_LIGHT: onset=320.660156, duration=0.0
# RAND_LIGHT: onset=322.960938, duration=0.0
# RAND_LIGHT: onset=325.261719, duration=0.0
